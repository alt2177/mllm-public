# %% [markdown]
# # Data Visualization
#
# This notebook is meant for data visualization and (potential) preprocessing before using the data for model training. Our data is stored on XetHub, and we will use the Python SDK they provide to access our data without the need for local copies.
#
# First, installation of `pyxet` and other dependencies:

# %%
# %pip install pyxet
# %pip install polars
# %pip install pandas
# %pip install numpy
# %pip install pyarrow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install datasets
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyxet         # make xet:// protocol available   
import pandas as pd 
import polars as pl  # faster alternative to pandas
import numpy as np
import pyarrow
import matplotlib
import matplotlib.pyplot as plt

# fix matplotlib error
matplotlib.rcParams.update(
    {
        'text.usetex': False,
        'font.family': 'stixgeneral',
        'mathtext.fontset': 'stix',
    }
)

fs = pyxet.XetFS()

# %% [markdown]
# # Drug Review Dataset (UCI)

# %%
# get the drug training and testing data
df_drugs_train = pl.read_csv('xet://drug_data/drugsComTrain_raw.tsv', separator = '\t')
df_drugs_test = pl.read_csv('xet://drug_data/drugsComTest_raw.tsv', separator = '\t')
print(df_drugs_train.shape)
print(df_drugs_test.shape)
df_drugs_train.head(10)
# Out:
# (161297, 7)
# (53766, 7)
# shape: (10, 7)
# ┌────────┬──────────────────┬──────────────────┬─────────────────┬────────┬─────────────────┬─────────────┐
# │        ┆ drugName         ┆ condition        ┆ review          ┆ rating ┆ date            ┆ usefulCount │
# │ ---    ┆ ---              ┆ ---              ┆ ---             ┆ ---    ┆ ---             ┆ ---         │
# │ i64    ┆ str              ┆ str              ┆ str             ┆ f64    ┆ str             ┆ i64         │
# ╞════════╪══════════════════╪══════════════════╪═════════════════╪════════╪═════════════════╪═════════════╡
# │ 206461 ┆ Valsartan        ┆ Left Ventricular ┆ "It has no side ┆ 9.0    ┆ May 20, 2012    ┆ 27          │
# │        ┆                  ┆ Dysfunction      ┆ effect, I take  ┆        ┆                 ┆             │
# │        ┆                  ┆                  ┆ i…              ┆        ┆                 ┆             │
# │ 95260  ┆ Guanfacine       ┆ ADHD             ┆ "My son is      ┆ 8.0    ┆ April 27, 2010  ┆ 192         │
# │        ┆                  ┆                  ┆ halfway through ┆        ┆                 ┆             │
# │        ┆                  ┆                  ┆ his f…          ┆        ┆                 ┆             │
# │ 92703  ┆ Lybrel           ┆ Birth Control    ┆ "I used to take ┆ 5.0    ┆ December 14,    ┆ 17          │
# │        ┆                  ┆                  ┆ another oral    ┆        ┆ 2009            ┆             │
# │        ┆                  ┆                  ┆ con…            ┆        ┆                 ┆             │
# │ 138000 ┆ Ortho Evra       ┆ Birth Control    ┆ "This is my     ┆ 8.0    ┆ November 3,     ┆ 10          │
# │        ┆                  ┆                  ┆ first time      ┆        ┆ 2015            ┆             │
# │        ┆                  ┆                  ┆ using any…      ┆        ┆                 ┆             │
# │ …      ┆ …                ┆ …                ┆ …               ┆ …      ┆ …               ┆ …           │
# │ 165907 ┆ Levonorgestrel   ┆ Emergency        ┆ "He pulled out, ┆ 1.0    ┆ March 7, 2017   ┆ 5           │
# │        ┆                  ┆ Contraception    ┆ but he cummed a ┆        ┆                 ┆             │
# │        ┆                  ┆                  ┆ …               ┆        ┆                 ┆             │
# │ 102654 ┆ Aripiprazole     ┆ Bipolar Disorde  ┆ "Abilify        ┆ 10.0   ┆ March 14, 2015  ┆ 32          │
# │        ┆                  ┆                  ┆ changed my      ┆        ┆                 ┆             │
# │        ┆                  ┆                  ┆ life. There …   ┆        ┆                 ┆             │
# │ 74811  ┆ Keppra           ┆ Epilepsy         ┆ " I Ve had      ┆ 1.0    ┆ August 9, 2016  ┆ 11          │
# │        ┆                  ┆                  ┆ nothing but     ┆        ┆                 ┆             │
# │        ┆                  ┆                  ┆ problems…       ┆        ┆                 ┆             │
# │ 48928  ┆ Ethinyl          ┆ Birth Control    ┆ "I had been on  ┆ 8.0    ┆ December 8,     ┆ 1           │
# │        ┆ estradiol /      ┆                  ┆ the pill for    ┆        ┆ 2016            ┆             │
# │        ┆ levonorgestr…    ┆                  ┆ many…           ┆        ┆                 ┆             │
# └────────┴──────────────────┴──────────────────┴─────────────────┴────────┴─────────────────┴─────────────┘

# %%
df_drugs_train["review"][0]
# Out:
# '"It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil"'

# %%
print(df_drugs_train.select("rating"))

# create scatter plot
plt.figure(figsize = (10, 6))

# Remove top and 
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# labels
plt.hist(df_drugs_train.select("rating"))
plt.title("Predicting `MedHouseval` on `MedInc`")
plt.xlabel('MedInc')
plt.ylabel('MedHouseVal')
plt.legend()
plt.savefig("images/rating_distribution.png")
plt.show()

# %% [markdown]
# ## Data Description / Visualization

# %% [markdown]
# ### Training Data

# %%
# df_drugs_train.dtypes  #= [Int64, String, String, String, Float64, String, Int64]
df_drugs_train.describe()
df_drugs_train.select(pl.all().is_null().sum())

#df_drugs_train.select(['rating']).unique()
# for cond in df_drugs_train.select(['condition']).unique()['condition']:
#     print(cond)
# for drug in df_drugs_train.select(['drugName']).unique()['drugName']:
#     print(drug)
# for rev in df_drugs_train.select(['review']).unique()['review'][0:20]:
#     print(rev)

review_word_count = df_drugs_train.select(['review']).map_rows(lambda t: len(t[0].split(" ")))
#plt.hist(review_word_count)
review_word_count.describe()
plt.hist(df_drugs_train['rating'], bins = 10)
plt.title("Distribution of Rating")
plt.savefig("rating_dist")
plt.hist(df_drugs_train['usefulCount'], bins = 100)
#df_drugs_train.select(['usefulCount']).unique()
# Out:
# Installed osx event loop hook.
# (array([6.8706e+04, 3.4865e+04, 1.9948e+04, 1.2270e+04, 7.7870e+03,
#         5.4130e+03, 3.5430e+03, 2.3550e+03, 1.7390e+03, 1.2150e+03,
#         8.4500e+02, 5.6100e+02, 4.6600e+02, 3.3600e+02, 2.7500e+02,
#         1.8000e+02, 1.5500e+02, 1.1100e+02, 1.0300e+02, 6.1000e+01,
#         6.2000e+01, 4.1000e+01, 4.1000e+01, 3.1000e+01, 3.3000e+01,
#         2.2000e+01, 2.4000e+01, 1.1000e+01, 1.4000e+01, 4.0000e+00,
#         1.2000e+01, 8.0000e+00, 5.0000e+00, 3.0000e+00, 6.0000e+00,
#         6.0000e+00, 4.0000e+00, 4.0000e+00, 2.0000e+00, 5.0000e+00,
#         4.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 4.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00,
#         0.0000e+00, 2.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 2.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([   0.  ,   12.91,   25.82,   38.73,   51.64,   64.55,   77.46,
#           90.37,  103.28,  116.19,  129.1 ,  142.01,  154.92,  167.83,
#          180.74,  193.65,  206.56,  219.47,  232.38,  245.29,  258.2 ,
#          271.11,  284.02,  296.93,  309.84,  322.75,  335.66,  348.57,
#          361.48,  374.39,  387.3 ,  400.21,  413.12,  426.03,  438.94,
#          451.85,  464.76,  477.67,  490.58,  503.49,  516.4 ,  529.31,
#          542.22,  555.13,  568.04,  580.95,  593.86,  606.77,  619.68,
#          632.59,  645.5 ,  658.41,  671.32,  684.23,  697.14,  710.05,
#          722.96,  735.87,  748.78,  761.69,  774.6 ,  787.51,  800.42,
#          813.33,  826.24,  839.15,  852.06,  864.97,  877.88,  890.79,
#          903.7 ,  916.61,  929.52,  942.43,  955.34,  968.25,  981.16,
#          994.07, 1006.98, 1019.89, 1032.8 , 1045.71, 1058.62, 1071.53,
#         1084.44, 1097.35, 1110.26, 1123.17, 1136.08, 1148.99, 1161.9 ,
#         1174.81, 1187.72, 1200.63, 1213.54, 1226.45, 1239.36, 1252.27,
#         1265.18, 1278.09, 1291.  ]),
#  <BarContainer object of 100 artists>)

# %%
# FOR INTERIM REPORT
from datasets import load_dataset

dataset = load_dataset("billsum")

# %%
billsum_train = dataset["train"]

# Remove top and 
plt.figure(figsize = (10, 6))
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.hist(billsum_train["text"], bins = 30)
plt.title(f'Distribution of Text Feature')
plt.xlabel("text")
plt.ylabel('Frequency')
# plt.savefig("images/billsum_text_dist.png")
plt.show()
# Out:
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26 () missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print(np.quantile(review_word_count, 0.95))
print(np.quantile(review_word_count, 0.05)) # 14 words

for rev in df_drugs_train.filter(review_word_count['map'] < 5)['review']:
   print(rev.strip('\n'))


#    print()
#review_word_count
#df_drugs_train.filter(review_word_count['map'] > 1000)['review']
#df_drugs_train.filter(review_word_count['map'] < 5)['review']
# Out:
# 147.0
# 14.0
# "It works very well"
# "Accurate information."
# "All the side effects"
# "Headache"
# "Works every time."
# "Stops the pain."
# "Dont know..."
# "Diarrhea a side effect."
# "Caused breathing problems."
# "Unbelievably good."
# "Very effective."
# "Great"
# "Great miracle."
# "Absolute BEST "
# "Pain in joints,,nausea,abd. Pain"
# "Good for breathing"
# "Good medicine"
# "Worked well for me"
# "Suicidal thoughts"
# "Awesome"
# "expensive"
# "Good"
# "Amazing."
# "Terrible akathisia."
# "It works."
# "It works."
# "Makes me nauseated"
# "I loved it!!!!"
# "Works great!"
# "Very expensive 700dls"
# "Great!"
# "It changed my life."
# "Very effective for me."
# "Excellent"
# "Helped mildly shortly"
# "It is very helpful."
# "This works great."
# "Helped a lot."
# "Sleepy but helpful"
# "Helped a lot."
# "Very good."
# "Miraculous"
# "This explains my insomnia"
# "I am gaining weight."
# "Caused restless leg syndrome."
# "Excellent medicine....don&#039;t hesitate."
# "Helps very much"
# "Positive"
# "Experience tiredness, no energy."
# "Great!"
# "wonderful"
# "35 years on ativan"
# "It was very helpful."
# "No problems"
# "Expensive garbage"
# "Good."
# "It works really well."
# "Severe withdrawal"
# "This medicine really works."
# "Works great for cough."
# "calms you down instantly"
# "It&#039;s okay"
# "Rotator cuff."
# "Reduced burning significantly"
# "Severe constipation"
# "Joint pain in elbow."
# "Treated"
# "side effects RARE"
# "Cannot sleep on Remeron"
# "Just works without trying!"
# "Best I ever had!"
# "It is magic"
# "Patch don&#039;t stay on"
# "Great"
# "Felt human within days!"
# "Great miracle."
# "12 hours, 140 mg."
# "Didn&#039;t help at all."
# "Autumn depression"
# "Love it love it"
# "So far, so good!!"
# "Caused sweating, headache."
# "awesome"
# "Extremely helpful!"
# "Just average"
# "Sure, does work."
# "This medicine really helps."
# "Best anti-anxiety medicine."
# "Very good"
# "Amazing results!"
# "I loved it!!!!"
# "Works for me."
# "good experience."
# "Still in pain."
# "Does little to nothing."
# "Works well."
# "Not good."
# "Stopped the diarrhea. "
# "great"
# "This works great."
# "I loved it !!"
# "Allows me to function."
# "It helps"
# "weight gain; tinnitus"
# "Causes dizziness, dry mouth."
# "A+++"
# "good"
# "Effective and not irritating"
# "it is very effective!"
# "Great. Fell asleep."
# "Work good"
# "Causes intense sweating"
# "very helpful"
# "started to go blind"
# "Weight gain"
# "No relief."
# "Fair"
# "Slowly getting recovered"
# "Unable to urinate."
# "Good"
# "Severe allergic reaction."
# "Great results."
# "Great for panic disorder."
# "Helped a lot."
# "Coughing worse after taking"
# "Good"
# "Awesome pain relief."
# "Works great."
# "Very well tolerated"
# "They work very well"
# "It works"
# "Wonderful medication!!"
# "Works ok"
# "Did not worl"
# "Sleeplessness"
# "Best I ever had!"
# "Very good"
# "Had trouble sleeping."
# "Good experience with prozac"
# "For jet-lag."
# "Caused hair loss."
# "Great."
# "Works great but expensive"
# "exellent"
# "Its great."
# "So far I"
# "Awesome stuff"
# "Works great."
# "Itchy beyond belief!"
# "Very good."
# "Works Great"
# "Terrible withdrawal symptoms. "
# "Works fantastic."
# "Works great, strong stuff."
# "Great drug."
# "Excellent"
# "No after effects."
# "Good."
# "Works really well."
# "Was relieved"
# "Not sure yet."
# "I pee now"
# "very easy to take"
# "Lifesaver drug!!!"
# "Best medicine by far."
# "It always works!"
# "Great on &quot;school sores&quot;"
# "Caused tiredness and constipation."
# "Best medicine ever"
# "Has no side effects."
# "was  great."
# "Did not work"
# "Great ...I&#039;m not pregnant."
# "Pain with the injection"
# "Great"
# "Works great, almost immediate."
# "Did not work"
# "Fast recovering."
# "Minimum adverse effects. "
# "Cannot tolerate restlessness"
# "No side effects."
# "Great medication"
# "Works great, really helps"
# "Definitely relieves my headache."
# "Great for rescue nebulizer."
# "I kept waking up"
# "It makes me dizzy."
# "100% effective."
# "Very effective."
# "Works very effectively. "
# "Lifted my deep depression!"
# "Took the edge off."
# "Very good for pain"
# "Lyrica works! "
# "Works effectively"
# "Good."
# "Horrible drug. Avoid it"
# "Amazing! Perfect!"
# "It works"
# "Great"
# "Miracle drug"
# "Great. Fell asleep."
# "Awesome"
# "Only downfall is price."
# "A miracle medicine."
# "Great for pain relief."
# "It works!"
# "Great!"
# "Not working right"
# "It&#039;s awesome."
# "Leaves a big bruise"
# "Good for nerve damage."
# "Works great"
# "Worst side effects ever!!!!!!!"
# "One word. Wonderful!"
# "Best medicine for anxiety."
# "Good"
# "Is great for pain."
# "Wonderful"
# "Not bad"
# "nausea"
# "wow."
# "This generic doesn&#039;t work"
# "Optimal"
# "Zoloft is really good."
# "Side effect, swollen ankles."
# "Changed my life."
# "bad"
# "Hated it"
# "Works well. Popular brand."
# "Double hernia"
# "Stopped my seizures. "
# "didnt work"
# "Not effective as oxycodone"
# "Works good for me."
# "It helped."
# "Not covered by insurance"
# "Nitrofurantoin caused extreme nausea."
# "Best one out there."
# "It actually works."
# "Not prescribed enough"
# "It worked."
# "Wonderful takes stress away"
# "Bad at best"
# "Even 30 mg works!"
# "Very good"
# "good"
# "This works great."
# "Wonderful medication!!"
# "Diarrhea...enough said."
# "Good"
# "Works well, some sleepiness."
# "They work!"
# "Seems to work."
# "The best ever!!!!"
# "Changed my life!"
# "Good"
# "Horrible side effects."
# "Works extremely well."
# "Working very good"
# "Amrix is so effective."
# "its awesome"
# "I can finally focus"
# "Good Results"
# "it was good"
# "Worked very well."
# "The best ever."
# "LOVE IT! No complaints."
# "Works well for me."
# "Relieves most allergy symptoms."
# "This worked wonders!"
# "Serious allergy developed."
# "Bloating swelling"
# "Works great."
# "bad side effects"
# "Easy to use!"
# "Very good"
# "Great
# Effective
# Unbelievable"
# "Great"
# "Great for stopping cravings!"
# "Great medication ...miracle."
# "Exceptionelly great"
# "Well worth it."
# "Couldnt live without."
# "Life changing."
# "Had trouble sleeping."
# "I love it."
# "Great help."
# "Effective and not irritating"
# "It helps me. "
# "Not Good"
# "Good but created impotence."
# "Saved my life."
# "Doesn&#039;t work"
# "Did not help."
# "Allergic reaction, hives."
# "It helps a lot"
# "Horrible side effects."
# "Great."
# "Caused muscle aches."
# "Good Results"
# "Great drug."
# "Great so far."
# "Works effectively"
# "Very good medicine."
# "The best ever."
# "Works well, some sleepiness."
# "It works great."
# "It worked the best."
# "An itchy scalp."
# "Terrible hallucinations!"
# "Works well"
# "It works!!!!!!"
# "hi"
# "Worked really well!"
# "Best thing for pain."
# "Back surgery"
# "Nerve and back pain."
# "Very helpful medicine."
# "Worked well."
# "Great ...I&#039;m not pregnant."
# "Great for insomnia."
# "It is good."
# "Worked within 24 hrs"
# "I feel better."
# "Very good"
# "Back surgery"
# "Dumb drug under tested"
# "Stopped craving"
# "Works great!"
# "(escitalopram)"
# "Happy thoughts once again."
# "Works very well."
# "Hot flashes"
# "Thankfully, this really works."
# "Just started"
# "Made me irritable."
# "Very expensive though."
# "Works well."
# "Much superior to warfarin."
# "Excellent"
# "So far, so good."
# "Good."
# "Wonderful."
# "No noticeable side effects."
# "Excellent "
# "Working so far."
# "Dry mouth"
# "Experiencing gastritis"
# "Fantastic pain relief. "
# "Not helping pain!"
# "Made me very sick"
# "Cluster sufferer"
# "Has helped so much."
# "Works well "
# "This has helped me."
# "nightmares"
# "Caused suicidal depression"
# "Great!"
# "works great!"
# "Rapid weight gain!"
# "Very pleased with Lexapro."
# "Works Great"
# "Works great, really helps"
# "It works instantly."
# "Causes Constipation."
# "Nice"
# "Trying good results"
# "Great medicine for pain."
# "Leaves a big bruise"
# "Only thing that worked!"
# "cost"
# "Doesn&#039;t work for me."
# "It makes me tired"
# "Excellent results"
# "works"
# "STAY AWAY,Worst drug EVER!!!!!!!!!"
# "works"
# "Works awesome!"
# "The best."
# "My fianc"
# "Relaxed little toe."
# "Very Sickening."
# "Very effective."
# "Excellent for controlling diabetes."
# "It works!"
# "works for hernia surgery"
# "extreme increased anxiety"
# "Sleep well at night."
# "It works."
# "Great!"
# "Relaxed and calm"
# "Gave me rash/hives."
# "Works great."
# "Good, very good."
# "Not bad"
# "God send!"
# "Helps my anxiety tremendously!"
# "So far, life changing"
# "Great"
# "Great medication!"
# "Unbelievably good."
# "Excellent for opiate withdrawals."
# "Miracle medicine!"
# "It&#039;s good."
# "Having balance dizziness problem"
# "Great"
# "It works."
# "Works Well"
# "Serious allergy developed."
# "All the side effects"
# "Viagra. I salute you."
# "Works really well."
# "Worth every penny!"
# "Works well."
# "Wonderfully highly recommended"
# "it works."
# "works fast and well."
# "Anaphylaxis."
# "hooray"
# "Made me sick"
# "It works great."
# "Great for skin"
# "Partial seizure"
# "Took the edge off."
# "Caused suicidal thoughts."
# "amazing"
# "Didn&#039;t work for me."
# "Good so far"
# "Never a problem."
# "This &quot;medicine&quot; is awful!"
# "This worked great."
# "I"
# "It helps me. "
# "Lowered triglycerides dramatically."
# "Fast recovering."
# "Bad at best"
# "Nausea, night tremors."
# "Great medication for HIV...."
# "Good"
# "Fantastic"
# "Wonder Drug"
# "Great!"
# "Side effect: rash"
# "Awesomeness!"
# "It is the best."
# "Love this medicine."
# "Trouble sleeping,stomach pain,headache,constipation,fever,"
# "It works."
# "Great working medication."
# "Very effective"
# "Not good"
# "Helps me a lot."
# "Very moderate pain relief."
# "Very effective."
# "Great"
# "Awesome."
# "Made my cough worst."
# "Keeps me sober"
# "It works."
# "I cannot sleep. "
# "Wonderful drug."
# "Good medicine."
# "Works Like Magic!!!"
# "Works great. "
# "Tastes great."
# "Love it!"
# "Pain with the injection"
# "A good generic."
# "Did not worl"
# "Diarrhea a side effect."
# "This has helped me."
# "Works for me."
# "Over all good"
# "Makes you gain weight"
# "It actually worked"
# "Doesn&#039;t work at all"
# "It worked good."
# "Life saver"
# "Funny"
# "Experienced palpitations."
# "Aleve helps a lot"
# "It actually worked"
# "Price gouging"
# "It works."
# "Best nasal spray"
# "Wide awake"
# "Very good"
# "It&#039;s not for everyone."
# "This saved my life."
# "They really work."
# "Saved my life."
# "Horrible side effects."
# "Works great for me"
# "It works for pain."
# "pretty good."
# "Made my pain worse"
# "Works well."
# "I gained weight."
# "Excellent medicine."
# "Wiw"
# "It&#039;s a wonder drug."
# "Excellent"
# "Over all good"
# "Helped"
# "Just started it today"
# "Not long on it"
# "Best medicine for anxiety."
# "Highly effective"
# "Very expensive 700dls"
# "Menstrual cramps"
# "Great for Depression."
# "Great drug!"
# "Is good"
# "Very good"
# "Its great."
# "Works for me."
# "Good medicine."
# "Works great!"
# "working great"
# "Great for fibromyalgia"
# "Did not work"
# "it helps me"
# "Good adjunct with analgesics."
# "Achy back, trouble sleeping."
# "Constipation"
# "Definitely a good product."
# "Very helpful"
# "Great I lost weight"
# "Made me dizzy."
# "neuropathy"
# "Helped me get well"
# "Really good."
# "Great so far."
# "Good."
# "Works well for pain."
# "Best medicine by far."
# "Relieves tremor and dyskinesia.
# "
# "This is totally awesome."
# "Great!"
# "100% accurate."
# "Great!"
# "good"
# "not working"
# "Chapped hands"
# "It makes me mellow."
# "Works well for me."
# "great treatment"
# "It is amazing!"
# "completely stopped vaginal dryness."
# "Very effective. "
# "Did not work"
# "was  great."
# "Good medicine."
# "Rapid weight gain!"
# "Works great!"
# "Outstanding!"
# "It helped."
# "Fatigue
# Joint Pain
# Depression
# Loss of libido"
# "Caused nausea, dizziness"
# "Great medicine."
# "Better than glucophage alone."
# "Bad experience. Bad sleep."
# "Powerful."
# "great"
# "Minimum adverse effects. "
# "Works well"
# "Wonderful"
# "Has made me hypertensive."
# "Great for Depression."
# "Caused hair loss."
# "Saved my life."
# "I like it."
# "I felt brand new."
# "Works Amazingly!"
# "Love it"
# "severe depression and anxiety"
# "Nerve and back pain."
# "So helpful"
# "Fabulous medicine for schizophrenia"
# "Just started it today"
# "Works awesome!"
# "Excellent"
# "works great"
# "Awesome."
# "Excellent for this condition!!"
# "Caused severe heartburn!"
# "no effects yet"
# "it worked"
# "Heartbroken"
# "It&#039;s very helpful."
# "Very good."
# "Bad side effects."
# "Good efficacy."
# "Headaches: Problem solver."
# "works great"
# "Good medicine."
# "Best drug ever."
# "It&#039;s alright, nothing special"
# "Caused bad stomach upset."
# "loose of epilepsy control"
# "Good"
# "Expensive garbage"
# "AnnetAndre9"
# "Worked great."
# "Life changing."
# "Good result."
# "Caused nausea...but worked."
# "Very fast heart beat"
# "Changed my life!"
# "Helpful!"
# "A miracle medicine."
# "Works"
# "works great"
# "Great"
# "Relives pain fast"
# "Made my feet swell"
# "Just didn&#039;t work."
# "Works great and fast"
# "Busy mum."
# "cool"
# "Excellent product."
# "Helpful."
# "Good"
# "I fill better."
# "Worked very well."
# "Just happy with Cialis."
# "Works"
# "Awesomeness!"
# "Excellent... Very satisified."
# "Love it."
# "As expected"
# "Excellent!"
# "Condition improved very quickly."
# "I like it."
# "Helped stop hallucinations."
# "Great."
# "Copd for six years"
# "Works Great"
# "Weight loss and Diaharia."
# "It works good."
# "Doesn&#039;t work"
# "A life saver."
# "Headaches: Problem solver."
# "Good, very good."
# "Doesn&#039;t work at all"
# "Hair loss, persistent headache"
# "Excellent Source Material."
# "Its Amazing"
# "Excellent drug! Works miraculously!"
# "Good medicine."
# "Works great"
# "It didn&#039;t work."
# "Works well for me."
# "Old and reliable."
# "Very helpful!!"
# "Much better than Paxil"
# "Works good for me."
# "Saved my life."
# "Good stuff."
# "Helps every time"
# "Horrible horrible nausea"
# "Back pain, bone spurs"
# "Big help for vulvodynia."
# "Has helped me."
# "completely stopped vaginal dryness."
# "Its not helping me,"
# "Upset stomach."
# "Very effective for me."
# "It works."
# "Helps so much."
# "Weight gain."
# "Great help"
# "Copd for six years"
# "Just happy with Cialis."
# "Does the job."
# "Sleepiness memory loss."
# "It&#039;s been a miracle"
# "Lots of nausea"
# "Side effect. Swollen ankles"
# "I had weight gain."
# "Worked as described."
# "Not effective"
# "Awesome."
# "Very good."
# "Its a good painkiller."
# "Fantastic"
# "Best medicine for anxiety."
# "Didn&#039;t help at all"
# "Excellent results--very calming effect"
# "It helps 70 percent"
# "Good efficacy."
# "It works very well"
# "Works really fast. "
# "Good."
# "Helps me sleep"
# "Caused suicidal ideation"
# "Great for colds."
# "Sciatica pain"
# "exellent"
# "Lots of nausea"
# "It is good."
# "Beautiful sleep every night"
# "Very good"
# "I have Sj"
# "This works very well"
# "Good experience with prozac"
# "Very good"
# "Nailed my presentation!!!"
# "Miracle drug."
# "Relives pain fast"
# "it was okay"
# "Good"
# "Makes you gain weight"
# "Didn&#039;t work!"
# "extreme increased anxiety"
# "Good Information."
# "Extreme diarrhea"
# "works!"
# "Great."
# "Worked the first time!"
# "positive no side effects"
# "Caused weight gain."
# "Helps tremendously."
# "Enhances my acid reflux"
# "Works great"
# "Causes too many lows"
# "I gained weight."
# "Not effective as oxycodone"
# "Works for me!"
# "Very effective. "
# "Work well"
# "Made me irritable."
# "bad"
# "fast heartbeat"
# "Blessed and complete sleep."
# "Helps."
# "Great for back pain"
# "Works great!"
# "Very quick and effective."
# "Helps greatly."
# "No help with pain."
# "Mirapex helps me."
# "Optimal"
# "Did absolutely nothing."
# "Works great."
# "Miserable, bloated, abdominal cramps."
# "excellent"
# "sucks enough said"
# "it is very effective!"
# "It works great."
# "Horrible"
# "Amazing! Works so well!"
# "Immediatly soothes the pain."
# "Just didn&#039;t work."
# "Severe allergic reaction."
# "Easy to use!"
# "Caused severe heartburn!"
# "Great medication! Works wonders"
# "No side effects."
# "Great"
# "Works great but expensive."
# "Horrible"
# "Doesn&#039;t help my pain."
# "Worked great."
# "Just another addictive pill"
# "It is great."
# "Very good medicine."
# "Works"
# "Excellent for post-surgical spasm."
# "Works great!"
# "Great."
# "Keeps me sober"
# "Works beautifully."
# "Great for back pain"
# "Caused migraines."
# "Never a problem."
# "Works well."
# "Severe withdrawal"
# "Acne went completely away."
# "Positive"
# "Very good."
# "Found no side effects."
# "Thank you Valium!"
# "Best pain relief."
# "It&#039;s great."
# "Still in pain."
# "it helps me"
# "Makes me VERY drowsy."
# "It&#039;s great!"
# "Bad side effects!"
# "Didn&#039;t work at all"
# "Works great for anxiety."
# "Tramadol works. Period."
# "Good and effective antibiotic."
# "Excellent product."
# "Awesome stuff"
# "Weight gain"
# "Amazing presentation."
# "It works."
# "One word. Wonderful!"
# "Good"
# "Much superior to warfarin."
# "Best sleep medicine."
# "Horrible drug. Avoid it"
# "Helps control awful nausea."
# "overheating"
# "Not effective"
# "Severe vertigo, sweating, vomiting."
# "It works."
# "Very good and effective"
# "I love it"
# "STAY AWAY,Worst drug EVER!!!!!!!!!"
# "I love it."
# "Worked as described."
# "Caused excess morning sleep."
# "Just works without trying!"
# "Caused severe side effects."
# "Good."
# "very good"
# "Great for Panic disorder."
# "It really works."
# "Saved my life."
# "Amazing difference."
# "About like
# Placebo"
# "Worked great!"
# "It&#039;s working !!!"
# "Excellent"
# "Very effective."
# "It works good."
# "Works for me."
# "will ruin your life"
# "Made me really psychotic."
# "Caused sweating, headache."
# "Worked for me!"
# "Saved my life"
# "Experienced stomach flu conditions."
# "It works great."
# "Causes too many lows"
# "Best nasal spray"
# "Definitely helps."
# "Good"
# "Good with pain."
# "2 years"
# "Allergic reaction, hives."
# "No side effects."
# "Good medicine."
# "Immediatly soothes the pain."
# "Caused extreme fatigue"
# "Helps every time"
# "I like it."
# "Treated severe psoriasis."
# "Quick reduction of symptoms"
# "It&#039;s very helpful."
# "Prozac saved me."
# "Its Amazing"
# "Did not work"
# "This explains my insomnia"
# "It is very effective."
# "Changed my life."
# "Works great for me"
# "It works!"
# "Have not tried yet."
# "Works great. Love it."
# "Good medicine"
# "Nice dose counter"
# "Good"
# "Terrible. Enough said."
# "Very fast heart beat"
# "Good"
# "Very helpful"
# "THIS medicine works."
# "Been very helpful"
# "It worked fast."
# "Weight gain"
# "Seems to work well"
# "Nice."
# "It works"
# "No help with anxiety"
# "Been very helpful"
# "Great. Works everytime."
# "Works great for anxiety."
# "Experience tiredness, no energy."
# "Saved my life"
# "Doesn&#039;t work for me."
# "Minimal relief with itching"
# "Helped a lot."
# "Menstrual cramps"
# "Very good medicine."
# "Makes me shakey."
# "Has helped so much."
# "Not good enough"
# "I love it!"
# "Works great for anxiety."
# "Simply put a &quot;MIRACLE&quot;."
# "Works well."
# "Works amazingly!"
# "It is a miracle."
# "Great so far"
# "Works Great"
# "Works great"
# "Good"
# "This medication is Great."
# "It was good."
# "Side effect, swollen ankles."
# "A very effective drug."
# "Clonazepam is helping me"
# "Works decently."
# "Doesn&#039;t work."
# "I loved it!!!!"
# "good"
# "Excellent one time treatment"
# "This is magic"
# "Great"
# "Worked within 24 hrs"
# "Wonderful"
# "Effective in reducing discomfort"
# "Good! "
# "It is very help"
# "Lost 50 pounds"
# "Worked well."
# "garbage."
# "Very good"
# "Makes me VERY drowsy."
# "This is awesome."
# "Back Pain subsided"
# "Great"
# "G"
# "Great for stopping cravings!"
# "Lifesaver drug!!!"
# "Fabulous medicine for schizophrenia"
# "Good"
# "Works Like Magic!!!"
# "Gave me terrible headaches."
# "Headache"
# "This works very well"
# "Sleeplessness."
# "Minimal relief of pain"
# "Side effects were awful."
# "Elavil helped immediately."
# "Severe constipation"
# "This medicine is wonderful!"
# "Good for toothaches."
# "It works well. "
# "Changed my life."
# "It works great."
# "About 4hrs. A night."
# "Ok"
# "It works !"
# "love it"
# "Changed my whole life."
# "The best ever!!!!"
# "2nd try with suboxone.."
# "Good product"
# "Injection is the best."
# "not worth it"
# "Double hernia"
# "Didn&#039;t help much."
# "Very calm now."
# "99% symptom free."
# "God send!"
# "Great"
# "Need the right DR."
# "Great for Lupus."
# "Working very good"
# "It gave me cancer"
# "Good"
# "Felt human within days!"
# "Treated"
# "Didn&#039;t do a thing"
# "Great for rescue nebulizer."
# "Worked great!"
# "Working so far."
# "Absolute BEST "
# "Great working medication."
# "Wonder Drug"
# "Better sleep less PAIN"
# "Just started"
# "Helps me so much."
# "Stops the pain."
# "Fatigue
# Joint Pain
# Depression
# Loss of libido"
# "I love the Remeron."
# "It is great."
# "Helps"
# "Works great for me."
# "Good"
# "Worked for Me !!!!"
# "Restiril  for sleep"
# "very effective medicine"
# "Made me more sick."
# "Excellent finally some relief!"
# "Is good"
# "They work!"
# "Worked well!!!"
# "Great for muscle spasms"
# "Weight gain and fatigue."
# "Made my asthma better."
# "It works"
# "Definitely helps."
# "Better sleep less PAIN"
# "Good"
# "Therapeutic but dulling"
# "Best there is. Thanks."
# "This is magic"
# "Excellent headache reliever!"
# "Works great."
# "Works great for me."
# "It works"
# "Works well."
# "Awesome information."
# "Great medicine for depression."
# "Experienced palpitations."
# "Made me nauseous."
# "Terrible hallucinations!"
# "12 hours, 140 mg."
# "good"
# "Miracle pill."
# "Caused extreme fatigue"
# "Great medicine, Celexa."
# "Helps in-between flareups."
# "It is good."
# "Can&#039;t live without it."
# "Pharmacist."
# "AnnetAndre9"
# "Pain in joints,,nausea,abd. Pain"
# "Great!"
# "Very good"
# "Great for weight gain."
# "Good."
# "Didn&#039;t work!"
# "Great."
# "Advair gave me hypertension."
# "Caused muscle aches."
# "horrific,"
# "Immediate relief from vomiting/nausea."
# "Worked great."
# "Mirapex helps me."
# "Awake ..... Euphoria!"
# "Caused restless leg syndrome."
# "Great for panic disorder."
# "No side effects experienced."
# "It is truly amazing"
# "With Percocet 10mg."
# "Worth every penny!"
# "Excellent"
# "Excellent."
# "it was good"
# "Good stuff."
# "Stopped my seizures. "
# "Works amazing"
# "Really works"
# "Excellent"
# "Has changed my life."
# "Just rating."
# "It knocked me out."
# "Excellent for post-surgical spasm."
# "Constipation"
# "Clonidine works..period."
# "As expected"
# "No help with anxiety"
# "Miracle drug"
# "Good."
# "Highly effective"
# "Fantastic."
# "Lost without it."
# "Helps for spasms"
# "Very good"
# "Doesn&#039;t work"
# "Great for knee pain."
# "Relieves tremor and dyskinesia.
# "
# "Very helpful."
# "Awesome."
# "Very good"
# "Severe vertigo, sweating, vomiting."
# "Thank you Valium!"
# "Helps me sleep"
# "Works great for bronchitis"
# "This stuff doesn&#039;t work!!!"
# "This works great."
# "Takes away anxiety fast."
# "Saved my life."
# "Helps worrying a lot!"
# "Great after 6 wks."
# "Great"
# "Great experience!!"
# "Works better than percet.."
# "Works pretty good."
# "It gives me headaches."
# "Works."
# "Caused suicidal thoughts."
# "Awesome, worked as described."
# "Works Amazingly!"
# "Wonderful good sleep...."
# "I don&#039;t really know"
# "Amazing relief!"
# "Saw no affect"
# "Great. life changing."
# "Works very fast"
# "Love it!"
# "Extreme diarrhea"
# "Simply put a &quot;MIRACLE&quot;."
# "Excellent for obsessive thinking"
# "Works ok"
# "Best pain reliever."
# "It changed my life."
# "Just average"
# "Side effect: sexual dysfunction"
# "Well worth it."
# "joint stiffness, muscle weakness"
# "Insomnia, nausea"
# "I&#039;m allergic to it"
# "Headache, flatulence"
# "Back pain"
# "Good."
# "Very good"
# "Accutane is a miracle."
# "works very well."
# "Clonazepam is helping me"
# "Good for social Anxiety."
# "Positive"
# "Accutane is a miracle."
# "Anaphylaxis."
# "Therapeutic but dulling"
# "Exceptional."
# "Great immune booster."
# "Weird dreams"
# "overheating"
# "Didn&#039;t really help mynpain"
# "Works great for anxiety."
# "Very good, very fast."
# "Works great for me."
# "Thank you"
# "Chapped hands"
# "I"
# "Saved my life"
# "Morning everyone."
# "Improved patient compliance."
# "It&#039;s good."
# "works very well."
# "Miracle sleeping pill"
# "Makes me sleep"
# "Made me better"
# "It is great."
# "Big help for vulvodynia."
# "Great"
# "Works beautifully."
# "It&#039;s great."
# "This works very well"
# "Acne went completely away."
# "It really works."
# "Great"
# "Excellent "
# "Makes me shakey."
# "So far so good."
# "It really works ."
# "Ruptured tendons..."
# "4yrs no issues"
# "Hair loss, persistent headache"
# "Caused nausea...but worked."
# "Ok stuff"
# "Great immune booster."
# "Works Wonders!"
# "Works great for me"
# "No side effects"
# "Wonderful takes stress away"
# "The best medicine"
# "Amrix is so effective."
# "Best medicine ever"
# "Good"
# "Best anti-anxiety medicine yet."
# "Awesome."
# "Works well."
# "35 years on ativan"
# "Gave me rash/hives."
# "Great"
# "No help at all"
# "Awesome, works like magic!!"
# "I&#039;m still throwing up"
# "Really good."
# "Best thing ever"
# "Good and effective antibiotic."
# "It works excellently."
# "It was the best."
# "Good Information."
# "Worked great for this."
# "Great treatment!"
# "Great medicine, Celexa."
# "Good "
# "Caused weight gain."
# "Amazing.  Wonderful!"
# "works great"
# "Best pain reliever."
# "good"
# "Lowered levels immediately"
# "I love it!"
# "Awesome information."
# "Bad"
# "Awesome for pain."
# "Works great but expensive"
# "Heart palpitations. Scarey shakey"
# "Experiencing severe hair loss!!!!!!!!!"
# "Excellent."
# "Nitrofurantoin caused extreme nausea."
# "Good"
# "Very sedating."
# "Great medication for HIV...."
# "Excellent."
# "So far, life changing"
# "Works great"
# "Intense dreams nightmares"
# "Works for me."
# "Good"
# "Horrible yeast infection."
# "Worked okay."
# "Better than Ritalin. "
# "Severe diarrhea and fatigue"
# "Worked very well."
# "Good with pain."
# "Great."
# "Sleep well at night."
# "Good medicine."
# "I can finally focus"
# "I feel better."
# "Love it!"
# "-"
# "Works amazingly!"
# "Best of the best."
# "Great. life changing."
# "Helped pain a lot."
# "Good drug"
# "Worked well"
# "Very good"
# "Has changed my life."
# "Excellent"
# "Works wonders"
# "No side effects."
# "Helps very much"
# "Great for fibromyalgia"
# "Very good"
# "I just started taking"
# "Helps me a lot."
# "Great."
# "Works great"
# "Very nice"
# "Good"
# "No after effects."
# "Excellent product"
# "Ruptured tendons..."
# "Horrible"
# "Works great. Calming."
# "Love it."
# "Didn&#039;t work for me."
# "Excellent!"
# "Constipation"
# "Very helpful for RSD."
# "Awesome for pain."
# "Works great. Calming."
# "2 thumbs up!"
# "Okay"
# "Sorted me out good."
# "Best thing for pain."
# "Did not help."
# "Works well."
# "Saved my life."
# "Helps me sleep"
# "Good so far"
# "horrible
# but effective"
# "Ativan saved my life."
# "Worked okay."
# "Preferred to others."
# "Caused severe side effects."
# "I&#039;m allergic to it"
# "No relief at all."
# "So far so good."
# "Works great."
# "Side effect: sexual dysfunction"
# "It worked fast."
# "wow."
# "It is good."
# "Achy back, trouble sleeping."
# "Okay for panic disorder."
# "Wonderful but expensive."
# "Works great"
# "Works very effectively. "
# "It&#039;s working !!!"
# "Worked well for me."
# "neuropathy"
# "Allows me to function."
# "(escitalopram)"
# "It&#039;s awesome"
# "Didn&#039;t work for me."
# "It&#039;s not for everyone."
# "Worked well."
# "cost"
# "Seems to work well"
# "This drug is amazing."
# "works great!"
# "works great"
# "ok"
# "Terrible withdrawal symptoms. "
# "Did not work"
# "It works!"
# "Worked well for me"
# "No side effects!"
# "-"
# "Works well."
# "Wonderful drug."
# "Love it."
# "Great medication! Works wonders"
# "Works"
# "Changed my life!"
# "Good"
# "Great"
# "Works well. "
# "I fill better."
# "extensive harmless negative affects"
# "NIfedipine helps"
# "Good for breathing"
# "Worked very well."
# "I&#039;m healed!"
# "It works excellently."
# "Medication is working well."
# "Good."
# "works very well"
# "Gave me anxiety"
# "Caused hair loss"
# "Worked well"
# "Very good."
# "Super good for depression."
# "Works Well"
# "Definitely a good product."
# "Terrible side effects."
# "Itching"
# "Good"
# "It was very helpful."
# "Severe diarrhea after starting."
# "It was good."
# "not worth it"
# "Horrible breakouts!
# So disappointed."
# "god sent for anxiety"
# "Cannot sleep on Remeron"
# "Slight loosening of bowels"
# "Great."
# "It works good."
# "Caused bad stomach upset."
# "Severe diarrhea after starting."
# "Works great."
# "Didn&#039;t work well, constipation."
# "very bad mood swings."
# "Has had no effect"
# "Very expensive though."
# "It makes me dizzy."
# "started to go blind"
# "Good for toothaches."
# "Made me sleep great."
# "fatigue, headaches, muscle aches"
# "Works amazing"
# "Works for me"
# "Back Pain"
# "Good"
# "Amazing! Works so well!"
# "Not very good"
# "Works."
# "Had side effects."
# "Good."
# "Good."
# "It gives me headaches."
# "Wiw"
# "Busy mum."
# "Saved my life"
# "It is a miracle."
# "Good"
# "wow!!! what a difference!!!"
# "Good! "
# "Made me better"
# "Great for Lupus."
# "I love it."
# "It gave more energy"
# "Great."
# "Amazingly helpful."
# "Awesome"
# "Great medicine."
# "It knocked me out."
# "Feeling Great and normal"
# "Perfect experience."
# "Good adjunct with analgesics."
# "This drug is amazing."
# "Great for skin"
# "very good"
# "Excellent"
# "Need the right DR."
# "Good."
# "I won&#039;t stop bleeding"
# "Takes Care of anxiety."
# "Great pain relief."
# "Terrible akathisia."
# "It is very helpful."
# "Not very good"
# "Amazing medicine"
# "gave me yeast infection."
# "Caused hair loss"
# "Best anti-anxiety medicine."
# "Great."
# "Immediate Relief"
# "it works"
# "Good."
# "Great drug!"
# "Very good cough medication."
# "Kept my moods balanced"
# "just started"
# "Best drug ever."
# "Changed my life"
# "Awesome, works like magic!!"
# "Good."
# "Great for COPD patients."
# "Very good cough medication."
# "Good"
# "Good"
# "It&#039;s awesome"
# "Caused breathing problems."
# "Very pleased with Lexapro."
# "Very good."
# "Excellent drug! Works miraculously!"
# "Helps"
# "great treatment"
# " love it"
# "You won&#039;t be sorry."
# "Good."
# "Made my cough worst."
# "helped a bit"
# "This stuff doesn&#039;t work!!!"
# "Very effective."
# "Very good for me."
# "Diarrhea...enough said."
# "very good"
# "It works very fast."
# "Very good."
# "Good medicine."
# "I pee now"
# "Made me suicidal."
# "Great when used safely!"
# "Injection is the best."
# "No pain relief whatsoever."
# "Good"
# "Had side effects."
# "Helped VERY VERY MUCH!!!"
# "Been amazing for me"
# "Works well."
# "works great"
# "Helped stop hallucinations."
# "I&#039;m healed!"
# "Not working for me."
# "Gives me hope."
# "Side effect: rash"
# "Hard on the stomach."
# "Doesn&#039;t work."
# "Life changer"
# "It works wonders"
# "Not losing"
# "Good"
# "Great."
# "Great ..years of use."
# "No side effects."
# "Worked great for this."
# "This medicine is wonderful!"
# "It&#039;s simply a miracle."
# "I"
# "No side effects whatsoever!"
# "Amazing."
# "Helps greatly."
# "Some helpfulness"
# "Feeling Great and normal"
# "Terrible Side Effects"
# "Great."
# "Perfect!"
# "Good result."
# "Sleeplessness."
# "Very sedating."
# "works great"
# "Is the best!"
# "Wonderful."
# "Worked for Me !!!!"
# "Couldnt live without."
# "Diarrhea and rash"
# "Excellent Source Material."
# "Works very well."
# "Didn&#039;t notice any change."
# "Good"
# "Sour stomach"
# "Helped a great deal"
# "good results"
# "Beats  Acetaminophen"
# "Beautiful sleep every night"
# "hair loss, tiredness, constipation"
# "Great."
# "Definitely relieves my headache."
# "Helps control awful nausea."
# "Work good"
# "Effective but expensive."
# "Works great for me."
# "Miracle drug."
# "loss of vision"
# "Great experience!!"
# "Changed my life."
# "No side effects!"
# "Does not help."
# "Caused suicidal depression"
# "It is the best."
# "Love it."
# "Very expensive though."
# "Love it! Work&#039;s immediately."
# "Awake ..... Euphoria!"
# "The Best."
# "Works well for pain."
# "Extremely helpful!"
# "Ok"
# "It works really well."
# "Heart palpitations. Scarey shakey"
# "good"
# "Excellent results"
# "Doesn&#039;t work"
# "Just researching"
# "It&#039;s good."
# "Excellent product."
# "heray for pepto !!!"
# "light and fuzzy headed"
# "Great for backache."
# "Not good at all"
# "Doesnt work"
# "excellent"
# "Works great."
# "No side effects"
# "Excellent  experience"
# "Best one out there."
# "Only downfall is price."
# "Great medicine for pain."
# "Life-saving!"
# "Caused severe headaches."
# "The best."
# "Side effects were awful."
# "A sleeping pill. Terrible."
# "Heartbroken"
# "Made my asthma better."
# "Moderate"
# "I love it."
# "Works great for me!"
# "Insomnia, fatigue, confusion"
# "Causes really dark thoughts."
# "Great"
# "It was great"
# "Works well."
# "Not always effective."
# "very bad mood swings."
# "Severe diarrhea and nausea"
# "calms you down instantly"
# "It&#039;s great."
# "Just doesn&#039;t work"
# "Saved my life. "
# "Fantastic for my migraines."
# "Aleve helps a lot"
# "Generally positive experience"
# "Great help"
# "It did the job."
# "Very much effective.."
# "Absolute gold. "
# "Good strength and quality."
# "Gave me bad gas."
# "Lifesaver!"
# "Works great. Some drowsiness."
# "Hate it"
# "Suicidal thoughts"
# "Horrible horrible nausea"
# "Improved cognitive function....less confusion"
# "Helpful."
# "Great medicine"
# "Fantastic"
# "4yrs no issues"
# "Very good pain killer."
# "Love this medicine."
# "Saved my life."
# "Good."
# "useless"
# "No help with pain."
# "Restless legs worse"
# "Didn&#039;t work for me."
# "Awesome."
# "Working so far."
# "Saved my life!"
# "Works well for me."
# "Excellent,"
# "Great"
# "joint stiffness, muscle weakness"
# "Didn&#039;t help much."
# "Miracle medicine!"
# "Caused severe headaches."
# "Wide awake"
# "Extreme anxiety, exhausted"
# "Good"
# "Excellent"
# "Great. Works everytime."
# "Helped pain a lot."
# "This medicine is great"
# "Very helpful."
# "Experienced stomach flu conditions."
# "works great"
# "Great for insomnia."
# "Definitely effective."
# "Didn&#039;t notice any change."
# "Helps my pain 100%"
# "Great for atopic dermatitis."
# "Works for me greatly"
# "Worst side effects ever!!!!!!!"
# "This medication is Great."
# "Works great."
# "It opens your airways"
# "Made me sleep great."
# "Good medicine."
# "I love this medicine"
# "Horrible yeast infection."
# "Works"
# "No positive effect!"
# "Very good information."
# "Great!!! Just plain works"
# "Worked well. "
# "It worked good."
# "Itchy beyond belief!"
# "Very good."
# "So far so good."
# "Amazing medicine"
# "Changed my whole life."
# "Didnt help,"
# "amazing medication"
# "Relaxed little toe."
# "Brilliant"
# "Very good improvement"
# "Works Amazingly!"
# "No more pain."
# "it worked!"
# "It makes me tired"
# "Didn&#039;t work for me."
# "To early to tell."
# "Nice"
# "Calms mind for focus."

# %% [markdown]
# There are 5 reviews over 1000 words and two of them look identical. There might be more duplicates in the review column.

# %%
print("garbage")
# Out:
# garbage

# %% [markdown]
# Getting the basic descriptive stats, data types, etc.

# %%
# Get descripive stats
df_drugs_train.describe()
# Out:
# shape: (9, 8)
# ┌────────────┬─────────────┬─────────────┬─────────────┬────────────┬──────────┬────────────┬────────────┐
# │ describe   ┆             ┆ drugName    ┆ condition   ┆ review     ┆ rating   ┆ date       ┆ usefulCoun │
# │ ---        ┆ ---         ┆ ---         ┆ ---         ┆ ---        ┆ ---      ┆ ---        ┆ t          │
# │ str        ┆ f64         ┆ str         ┆ str         ┆ str        ┆ f64      ┆ str        ┆ ---        │
# │            ┆             ┆             ┆             ┆            ┆          ┆            ┆ f64        │
# ╞════════════╪═════════════╪═════════════╪═════════════╪════════════╪══════════╪════════════╪════════════╡
# │ count      ┆ 161297.0    ┆ 161297      ┆ 161297      ┆ 161297     ┆ 161297.0 ┆ 161297     ┆ 161297.0   │
# │ null_count ┆ 0.0         ┆ 0           ┆ 899         ┆ 0          ┆ 0.0      ┆ 0          ┆ 0.0        │
# │ mean       ┆ 115923.5853 ┆ null        ┆ null        ┆ null       ┆ 6.994377 ┆ null       ┆ 28.004755  │
# │            ┆ 05          ┆             ┆             ┆            ┆          ┆            ┆            │
# │ std        ┆ 67004.44517 ┆ null        ┆ null        ┆ null       ┆ 3.272329 ┆ null       ┆ 36.403742  │
# │ min        ┆ 2.0         ┆ A + D       ┆ 0</span>    ┆ "
#           ┆ 1.0      ┆ April 1,   ┆ 0.0        │
# │            ┆             ┆ Cracked     ┆ users found ┆
#            ┆          ┆ 2008       ┆            │
# │            ┆             ┆ Skin Relief ┆ this        ┆ please     ┆          ┆            ┆            │
# │            ┆             ┆             ┆ commen…     ┆ tell the   ┆          ┆            ┆            │
# │            ┆             ┆             ┆             ┆ ones who   ┆          ┆            ┆            │
# │            ┆             ┆             ┆             ┆ i…         ┆          ┆            ┆            │
# │ 25%        ┆ 58063.0     ┆ null        ┆ null        ┆ null       ┆ 5.0      ┆ null       ┆ 6.0        │
# │ 50%        ┆ 115744.0    ┆ null        ┆ null        ┆ null       ┆ 8.0      ┆ null       ┆ 16.0       │
# │ 75%        ┆ 173776.0    ┆ null        ┆ null        ┆ null       ┆ 10.0     ┆ null       ┆ 36.0       │
# │ max        ┆ 232291.0    ┆ femhrt      ┆ zen Shoulde ┆ "❤️❤️❤️       ┆ 10.0     ┆ September  ┆ 1291.0     │
# │            ┆             ┆             ┆             ┆ Cialis for ┆          ┆ 9, 2017    ┆            │
# │            ┆             ┆             ┆             ┆ US!!    I  ┆          ┆            ┆            │
# │            ┆             ┆             ┆             ┆ wis…       ┆          ┆            ┆            │
# └────────────┴─────────────┴─────────────┴─────────────┴────────────┴──────────┴────────────┴────────────┘

# %%
# get column names and their dtypes
df_drugs_train.schema
# Out:
# OrderedDict([('', Int64),
#              ('drugName', Utf8),
#              ('condition', Utf8),
#              ('review', Utf8),
#              ('rating', Float64),
#              ('date', Utf8),
#              ('usefulCount', Int64)])

# %%
# check if all the rows are unique 
print(df_drugs_train.is_unique().all())
# Out:
# True

# %%
# check for nulls
df_drugs_train.null_count()
# Out:
# shape: (1, 7)
# ┌─────┬──────────┬───────────┬────────┬────────┬──────┬─────────────┐
# │     ┆ drugName ┆ condition ┆ review ┆ rating ┆ date ┆ usefulCount │
# │ --- ┆ ---      ┆ ---       ┆ ---    ┆ ---    ┆ ---  ┆ ---         │
# │ u32 ┆ u32      ┆ u32       ┆ u32    ┆ u32    ┆ u32  ┆ u32         │
# ╞═════╪══════════╪═══════════╪════════╪════════╪══════╪═════════════╡
# │ 0   ┆ 0        ┆ 899       ┆ 0      ┆ 0      ┆ 0    ┆ 0           │
# └─────┴──────────┴───────────┴────────┴────────┴──────┴─────────────┘

# %% [markdown]
# Since there are over 800 `null` values in `condition`, let's take a closer look. This column represents the medical conditions of respondents, so we cannot just drop those. Instead, we fill with `not_reported`. This ensures no null values.

# %%
# fill missing values with "not_reported"
df_filled = df_drugs_train.with_columns(
    pl.col("condition").fill_null(pl.lit("not_reported")),
)

# check if we no longer have null values
print(df_filled.null_count())
# Out:
# shape: (1, 7)
# ┌─────┬──────────┬───────────┬────────┬────────┬──────┬─────────────┐
# │     ┆ drugName ┆ condition ┆ review ┆ rating ┆ date ┆ usefulCount │
# │ --- ┆ ---      ┆ ---       ┆ ---    ┆ ---    ┆ ---  ┆ ---         │
# │ u32 ┆ u32      ┆ u32       ┆ u32    ┆ u32    ┆ u32  ┆ u32         │
# ╞═════╪══════════╪═══════════╪════════╪════════╪══════╪═════════════╡
# │ 0   ┆ 0        ┆ 0         ┆ 0      ┆ 0      ┆ 0    ┆ 0           │
# └─────┴──────────┴───────────┴────────┴────────┴──────┴─────────────┘

# %% [markdown]
# ### Testing Data

# %% [markdown]
# # XSUM Dataset

# %%
# df_xsum = pl.from_pandas(pd.read_parquet('xet://xsum/predictions.parquet'))
# print(df_xsum.shape)
# df_xsum.head()
# Out:
# (11334, 3)
# shape: (5, 3)
# ┌───────────────────────────────────┬───────────────────────────────────┬────────────────────────┐
# │ text                              ┆ target                            ┆ evaluation_predictions │
# │ ---                               ┆ ---                               ┆ ---                    │
# │ str                               ┆ str                               ┆ list[i64]              │
# ╞═══════════════════════════════════╪═══════════════════════════════════╪════════════════════════╡
# │ Amina Al-Jeffery, 21, who was bo… ┆ A woman who claims her father ha… ┆ [0, 202, … 0]          │
# │ The concerns came amid Sportscot… ┆ JogScotland's future could be at… ┆ [0, 139, … 0]          │
# │ Backbench MPs can speak relative… ┆ Before Jeremy Corbyn became lead… ┆ [0, 9083, … 0]         │
# │ The company says the new overhea… ┆ Boeing has shown off its "space … ┆ [0, 23241, … 0]        │
# │ The vote held on Friday was for … ┆ The run-off parliamentary electi… ┆ [0, 139, … 0]          │
# └───────────────────────────────────┴───────────────────────────────────┴────────────────────────┘

# %% [markdown]
# # CNN/Dailymail Dataset

# %%
# files_cnn = fs.ls('xet://cnn_dailymail/1.0.0')
# df_dir = pl.from_dicts(files_cnn)
# print("==================== Current Working Dir ls =====================")
# print(df_dir.head())
# # print(df_dir.select(["name"]).head(1).item())
# df_cnn = pl.from_pandas(pd.read_parquet('xet://{}'.format(df_dir.select(["name"]).head(1).item())))
# # df_cnn = pl.from_pandas(pd.read_parquet('xet://cnn_dailymail/1.0.0/test-00000-of-00001.parquet'))
# print(df_cnn.shape)
# df_cnn.head()
# Out:
# ==================== Current Working Dir ls =====================
# shape: (5, 3)
# ┌───────────────────────────────────┬───────────┬──────┐
# │ name                              ┆ size      ┆ type │
# │ ---                               ┆ ---       ┆ ---  │
# │ str                               ┆ i64       ┆ str  │
# ╞═══════════════════════════════════╪═══════════╪══════╡
# │ cnn_… ┆ 29994057  ┆ file │
# │ cnn_… ┆ 256494215 ┆ file │
# │ cnn_… ┆ 256538980 ┆ file │
# │ cnn_… ┆ 259242781 ┆ file │
# │ cnn_… ┆ 34657215  ┆ file │
# └───────────────────────────────────┴───────────┴──────┘
# (11490, 3)
# shape: (5, 3)
# ┌────────────────────────────────┬────────────────────────────────┬────────────────────────────────┐
# │ article                        ┆ highlights                     ┆ id                             │
# │ ---                            ┆ ---                            ┆ ---                            │
# │ str                            ┆ str                            ┆ str                            │
# ╞════════════════════════════════╪════════════════════════════════╪════════════════════════════════╡
# │ (CNN)The Palestinian Authority ┆ Membership gives the ICC       ┆ f001ec5c4704938247d27a44948eeb │
# │ o…                             ┆ jurisdi…                       ┆ b3…                            │
# │ (CNN)Never mind cats having    ┆ Theia, a bully breed mix, was  ┆ 230c522854991d053fe98a718b1def │
# │ nine…                          ┆ ap…                            ┆ a0…                            │
# │ (CNN)If you've been following  ┆ Mohammad Javad Zarif has spent ┆ 4495ba8f3a340d97a9df1476f8a355 │
# │ th…                            ┆ m…                             ┆ 02…                            │
# │ (CNN)Five Americans who were   ┆ 17 Americans were exposed to   ┆ a38e72fed88684ec8d60dd5856282e │
# │ mon…                           ┆ the…                           ┆ 99…                            │
# │ (CNN)A Duke student has        ┆ Student is no longer on Duke   ┆ c27cf1b136cc270023de959e7ab246 │
# │ admitted…                      ┆ Uni…                           ┆ 38…                            │
# └────────────────────────────────┴────────────────────────────────┴────────────────────────────────┘
